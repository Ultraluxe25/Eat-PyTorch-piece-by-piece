# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Предшественником PyTorch стал Torch 7, написанный на Lua и C.

# %% [markdown]
# 18 января 2017 года был опубликован первый релиз PyTorch.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ранее глубокая нейронная сеть содержала от трех скрытых слоев.

# %% [markdown]
# Переменные, названия которых оканчивается на _t, представляют собой тензоры, хранимые в памяти CPU, на _g заканчиваются тензоры, хранимые в памяти GPU.

# %% [markdown]
# Для проработки книги нужно 200 GB SSD, NVIDIA GTX 1070 и 8 GB VRAM (у меня [RTX 5070 mobile, 8 GB VRAM, 4608 cuda](https://www.techpowerup.com/gpu-specs/geforce-rtx-5070-mobile.c4237))

# %% [markdown]
# Большая часть PyTorch написана на C++ и CUDA (APi между видеокартой NVIDIA и фреймворком глубокого обучения).

# %% [markdown]
# **PyTorch HUB** - платформа с набором моделей с примерами использования для обучения и инференса. **Инференс** - предсказание обученной модели на новых данных.

# %% [markdown]
# ![image.png](attachment:image.png)
